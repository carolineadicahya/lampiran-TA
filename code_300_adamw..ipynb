# %%
import ultralytics
from ultralytics import YOLO

# %%
import shutil
import os
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import sample

# %%
model_n = YOLO("yolo11n-seg.pt")

# %%
model_s = YOLO("yolo11s-seg.pt")

# %% [markdown]
# ## Tanpa Augmentasi

# %% [markdown]
# > epochs 300

# %%
results_n = model_n.train(data="D:/Caroline/Dataset Puddle no aug/data.yaml", epochs=300, optimizer="AdamW", lr0=0.002, momentum=0.9, weight_decay=0.0005, batch=16)
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
# pakai weight best.pt
modelmetrics_n = YOLO("D:/Caroline/runs/segment/train17/weights/best.pt")

# %%
metrics_n = modelmetrics_n.val()
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,834,763 parameters, 0 gradients, 10.2 GFLOPs
# val: Scanning D:\Caroline\Dataset Puddle no aug\valid\labels.cache... 483 images, 0 backgrounds, 0 corrupt: 100%|██████████| 483/483 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 31/31 [00:03<00:00,  9.58it/s]
#                    all        483        694      0.897      0.844      0.913      0.655      0.895      0.873      0.924      0.628
# Speed: 0.3ms preprocess, 2.0ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs\segment\val6

# %%
results_s = model_s.train(data="D:/Caroline/Dataset Puddle no aug/data.yaml", epochs=300, optimizer="AdamW", lr0=0.002, momentum=0.9, weight_decay=0.0005, batch=16)
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
# pakai weight best.pt
modelmetrics_s = YOLO("D:/Caroline/runs/segment/train24/weights/best.pt")

# %%
metrics_s = modelmetrics_s.val()
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLO11s-seg summary (fused): 113 layers, 10,067,203 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning D:\Caroline\Dataset Puddle no aug\valid\labels.cache... 483 images, 0 backgrounds, 0 corrupt: 100%|██████████| 483/483 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 31/31 [00:03<00:00,  7.99it/s]
#                    all        483        694      0.886      0.807      0.893      0.634      0.899      0.819        0.9      0.606
# Speed: 0.3ms preprocess, 3.1ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs\segment\val11

# %% [markdown]
# ## Dengan Augmentasi

# %% [markdown]
# > epochs 300

# %%
results_n_aug = model_n.train(data="D:/Caroline/Dataset Puddle v3/data.yaml", epochs=300, optimizer="AdamW", lr0=0.002, momentum=0.9, weight_decay=0.0005, batch=16)
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
# pakai weight best.pt
modelmetrics_n_aug = YOLO("D:/Caroline/runs/segment/train25/weights/best.pt")

# %%
metrics_n_aug = modelmetrics_n_aug.val()
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,834,763 parameters, 0 gradients, 10.2 GFLOPs
# val: Scanning D:\Caroline\Dataset Puddle v3\valid\labels.cache... 1155 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1155/1155 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 73/73 [00:06<00:00, 11.40it/s]
#                    all       1155       1968      0.974      0.933      0.978      0.824       0.98       0.93      0.978      0.761
# Speed: 0.2ms preprocess, 1.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs\segment\val12

# %%
results_s_aug = model_s.train(data="D:/Caroline/Dataset Puddle v3/data.yaml", epochs=300, optimizer="AdamW", lr0=0.002, momentum=0.9, weight_decay=0.0005, batch=16)
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %%
# pakai weight best.pt
modelmetrics_s_aug = YOLO("D:/Caroline/runs/segment/train26/weights/best.pt")

# %%
metrics_s_aug = modelmetrics_s_aug.val()
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLO11s-seg summary (fused): 113 layers, 10,067,203 parameters, 0 gradients, 35.3 GFLOPs
# val: Scanning D:\Caroline\Dataset Puddle v3\valid\labels.cache... 1155 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1155/1155 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 73/73 [00:07<00:00,  9.15it/s]
#                    all       1155       1968      0.967      0.945      0.977      0.847      0.969      0.946      0.975      0.782
# Speed: 0.2ms preprocess, 3.0ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs\segment\val13
